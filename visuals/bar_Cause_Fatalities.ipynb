# %%
#Setup
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# Style of Plots
plt.style.use('fivethirtyeight')

# Read files
df = pd.read_csv("Plane Crash dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb Cell 1' in <cell line: 11>()
#       <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000000?line=7'>8</a> plt.style.use('fivethirtyeight')
#      <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000000?line=9'>10</a> # Read files
# ---> <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000000?line=10'>11</a> df = pd.read_csv("Plane Crash dataset.csv")
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...

# %%
#Total Fatalities
print("all fatalities", df["Total fatalities"].sum())

category0 = 'Crash cause'
numeric0 = 'Total fatalities'

# group fatalities by cause:  https://datagy.io/pandas-groupby/
gb = df.groupby(category0)[numeric0].sum()
print("groupby as Series:") 
print(gb, type(gb))

# The issue (for me anyway) is that gb is not a dataframe, the left most "column"
# is its index (which can be non-numeric) and the right (unnamed) column has
# the actual values. Thing is you can't plot with that (x=index y=unnamed) so
# I'll create a new, separate df for plotting:

d = {category0: gb.index,
      numeric0: gb.values}
dfgb0 = pd.DataFrame(d)
dfgb0
print(dfgb0)

dfgb0.insert(2, "Fatalities", dfgb0['Total fatalities'], True)
numeric01 = 'Fatalities'

print(dfgb0)
# Out:
# all fatalities 158735
# groupby as Series:
# Crash cause
# Human factor         72955
# Other causes          4002
# Technical failure    29599
# Terrorism            12712
# Unknown              28614
# Weather              10853
# Name: Total fatalities, dtype: int64 <class 'pandas.core.series.Series'>
#          Crash cause  Total fatalities
# 0       Human factor             72955
# 1       Other causes              4002
# 2  Technical failure             29599
# 3          Terrorism             12712
# 4            Unknown             28614
# 5            Weather             10853
#          Crash cause  Total fatalities  Fatalities
# 0       Human factor             72955       72955
# 1       Other causes              4002        4002
# 2  Technical failure             29599       29599
# 3          Terrorism             12712       12712
# 4            Unknown             28614       28614
# 5            Weather             10853       10853

# %%
#Crew Fatalities
print("all fatalities", df["Crew fatalities"].sum())

category1 = 'Crash cause'
numeric1 = 'Crew fatalities'

# group fatalities by cause:  https://datagy.io/pandas-groupby/
gb = df.groupby(category1)[numeric1].sum()
print("groupby as Series:") 
print(gb, type(gb))

# The issue (for me anyway) is that gb is not a dataframe, the left most "column"
# is its index (which can be non-numeric) and the right (unnamed) column has
# the actual values. Thing is you can't plot with that (x=index y=unnamed) so
# I'll create a new, separate df for plotting:

d = {category1: gb.index,
      numeric1: gb.values}
dfgb1 = pd.DataFrame(d)
dfgb1

dfgb1.insert(2, "Fatalities", dfgb1['Crew fatalities'], True)
numeric01 = 'Fatalities'

print(dfgb1)
# Out:
# all fatalities 50469.0
# groupby as Series:
# Crash cause
# Human factor         18118.0
# Other causes           843.0
# Technical failure     8324.0
# Terrorism             4994.0
# Unknown              14989.0
# Weather               3201.0
# Name: Crew fatalities, dtype: float64 <class 'pandas.core.series.Series'>
#          Crash cause  Crew fatalities  Fatalities
# 0       Human factor          18118.0     18118.0
# 1       Other causes            843.0       843.0
# 2  Technical failure           8324.0      8324.0
# 3          Terrorism           4994.0      4994.0
# 4            Unknown          14989.0     14989.0
# 5            Weather           3201.0      3201.0

# %%
#Passenger Fatalities
print("all fatalities", df["PAX fatalities"].sum())

category2 = 'Crash cause'
numeric2 = 'PAX fatalities'

# group fatalities by cause:  https://datagy.io/pandas-groupby/
gb = df.groupby(category2)[numeric2].sum()
print("groupby as Series:") 
print(gb, type(gb))

# The issue (for me anyway) is that gb is not a dataframe, the left most "column"
# is its index (which can be non-numeric) and the right (unnamed) column has
# the actual values. Thing is you can't plot with that (x=index y=unnamed) so
# I'll create a new, separate df for plotting:

d = {category2: gb.index,
      numeric2: gb.values}
dfgb2 = pd.DataFrame(d)
dfgb2

dfgb2.insert(2, "Fatalities", dfgb2['PAX fatalities'], True)
numeric2 = 'Fatalities'

print(dfgb2)
# Out:
# all fatalities 104956.0
# groupby as Series:
# Crash cause
# Human factor         53247.0
# Other causes          2746.0
# Technical failure    20540.0
# Terrorism             7638.0
# Unknown              13300.0
# Weather               7485.0
# Name: PAX fatalities, dtype: float64 <class 'pandas.core.series.Series'>
#          Crash cause  PAX fatalities  Fatalities
# 0       Human factor         53247.0     53247.0
# 1       Other causes          2746.0      2746.0
# 2  Technical failure         20540.0     20540.0
# 3          Terrorism          7638.0      7638.0
# 4            Unknown         13300.0     13300.0
# 5            Weather          7485.0      7485.0

# %%
#Other Fatalities
print("all fatalities", df["Other fatalities"].sum())

category3 = 'Crash cause'
numeric3 = 'Other fatalities'

# group fatalities by cause:  https://datagy.io/pandas-groupby/
gb = df.groupby(category3)[numeric3].sum()
print("groupby as Series:") 
print(gb, type(gb))

# The issue (for me anyway) is that gb is not a dataframe, the left most "column"
# is its index (which can be non-numeric) and the right (unnamed) column has
# the actual values. Thing is you can't plot with that (x=index y=unnamed) so
# I'll create a new, separate df for plotting:

d = {category3: gb.index,
      numeric3: gb.values}
dfgb3 = pd.DataFrame(d)
dfgb3

dfgb3.insert(2, "Fatalities", dfgb3['Other fatalities'], True)
numeric01 = 'Fatalities'

print(dfgb0)
# Out:
# all fatalities 3125.0
# groupby as Series:
# Crash cause
# Human factor         1533.0
# Other causes          397.0
# Technical failure     708.0
# Terrorism              73.0
# Unknown               268.0
# Weather               146.0
# Name: Other fatalities, dtype: float64 <class 'pandas.core.series.Series'>
#          Crash cause  Total fatalities  Fatalities
# 0       Human factor             72955       72955
# 1       Other causes              4002        4002
# 2  Technical failure             29599       29599
# 3          Terrorism             12712       12712
# 4            Unknown             28614       28614
# 5            Weather             10853       10853

# %%
#Sorting
dfgb0.sort_values(by=[numeric0], ascending=False, inplace=True)
dfgb0

dfgb1.sort_values(by=[numeric1], ascending=False, inplace=True)
dfgb1

dfgb2.sort_values(by=[numeric2], ascending=False, inplace=True)
dfgb2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb Cell 6' in <cell line: 5>()
#       <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000005?line=1'>2</a> dfgb0.sort_values(by=[numeric0], ascending=False, inplace=True)
#       <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000005?line=2'>3</a> dfgb0
# ----> <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000005?line=4'>5</a> dfgb1.sort_values(by=[numeric1], ascending=False, inplace=True)
#       <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000005?line=5'>6</a> dfgb1
# ...

# %%
#Text Wrap
import textwrap
# https://medium.com/dunder-data/automatically-wrap-graph-labels-in-matplotlib-and-seaborn-a48740bc9ce
def wrap_labels(ax, width, break_long_words=False):
    labels = []
    for label in ax.get_xticklabels():
        text = label.get_text()
        labels.append(textwrap.fill(text, width=width,
                      break_long_words=break_long_words))
    ax.set_xticklabels(labels, rotation=0)

# %%
# Total Deaths Graph
import seaborn as sns

plt.style.use('fivethirtyeight') # works but you should also check out the seaborn themes
fig, ax = plt.subplots(figsize=(12, 6)) 
ax = sns.barplot(x=category, y=numeric, # which columns for x and y
                    data=dfgb, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 

# wrap x labels
wrap_labels(ax, 10)
ax.set_title('Total Deaths by Cause')
ax.set(ylim=(0, 75000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb Cell 8' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000007?line=3'>4</a> plt.style.use('fivethirtyeight') # works but you should also check out the seaborn themes
#       <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000007?line=4'>5</a> fig, ax = plt.subplots(figsize=(12, 6))
# ----> <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000007?line=5'>6</a> ax = sns.barplot(x=category, y=numeric, # which columns for x and y
# ...

# %%
# Crew Deaths Graph
import seaborn as sns

plt.style.use('fivethirtyeight') # works but you should also check out the seaborn themes
fig, ax = plt.subplots(figsize=(12, 6)) 
ax = sns.barplot(x=category, y=numeric, # which columns for x and y
                    data=dfgb, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 

# wrap x labels
wrap_labels(ax, 10)
ax.set_title('Crew Deaths by Cause')
ax.set(ylim=(0, 75000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb Cell 9' in <cell line: 6>()
#       <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000008?line=3'>4</a> plt.style.use('fivethirtyeight') # works but you should also check out the seaborn themes
#       <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000008?line=4'>5</a> fig, ax = plt.subplots(figsize=(12, 6))
# ----> <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000008?line=5'>6</a> ax = sns.barplot(x=category, y=numeric, # which columns for x and y
# ...

# %%
# Passengar Death Graphs

import seaborn as sns

plt.style.use('fivethirtyeight') # works but you should also check out the seaborn themes
fig, ax = plt.subplots(figsize=(12, 6)) 
ax = sns.barplot(x=category, y=numeric, # which columns for x and y
                    data=dfgb, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 

# wrap x labels
wrap_labels(ax, 10)
ax.set_ylabel('Passenger Deaths')
ax.set_title('Passenger Deaths by Cause')
ax.set(ylim=(0, 75000))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb Cell 10' in <cell line: 7>()
#       <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000009?line=4'>5</a> plt.style.use('fivethirtyeight') # works but you should also check out the seaborn themes
#       <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000009?line=5'>6</a> fig, ax = plt.subplots(figsize=(12, 6))
# ----> <a href='vscode-notebook-cell:/Users/spencergoergen/Documents/HCI_Project/visuals/bar_Cause_Fatalities.ipynb#ch0000009?line=6'>7</a> ax = sns.barplot(x=category, y=numeric, # which columns for x and y
# ...

# %%
# Other Death Graphs

import seaborn as sns

plt.style.use('fivethirtyeight') # works but you should also check out the seaborn themes
fig, ax = plt.subplots(figsize=(12, 6)) 
ax = sns.barplot(x=category3, y=numeric3, # which columns for x and y
                    data=dfgb3, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 

# wrap x labels
wrap_labels(ax, 10)
ax.set_ylabel('Other Deaths')
ax.set_title('Other Deaths by Cause')
ax.set(ylim=(0, 75000))
# Out:
# [(0.0, 75000.0)]

# %%
# 4 graphs linear
import seaborn as sns

plt.style.use('fivethirtyeight') # works but you should also check out the seaborn themes
fig, ax = plt.subplots(1,4,figsize=(25, 7), sharey=True) 
sns.barplot(ax=ax[0], x=category0, y=numeric0, # which columns for x and y
                    data=dfgb0, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 
ax[0].set_title('Total Deaths by Cause')
ax[0].set(ylim=(0, 75000))
ax[0].set_ylabel('')
ax[0].set_xticklabels(ax[0].get_xticklabels(),rotation = 90)

sns.barplot(ax=ax[1], x=category1, y=numeric1, # which columns for x and y
                    data=dfgb1, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 
ax[1].set_title('Crew Deaths by Cause')
ax[1].set(ylim=(0, 75000))
ax[1].set_ylabel('')
ax[1].set_xticklabels(ax[1].get_xticklabels(),rotation = 90)

sns.barplot(ax=ax[2], x=category2, y=numeric2, # which columns for x and y
                    data=dfgb2, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 
ax[2].set_title('Passenger Deaths by Cause')
ax[2].set(ylim=(0, 75000))
ax[2].set_ylabel('')
ax[2].set_xticklabels(ax[2].get_xticklabels(),rotation = 90)

sns.barplot(ax=ax[3], x=category3, y=numeric3, # which columns for x and y
                    data=dfgb3, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 
ax[3].set_title('Other Deaths by Cause')
ax[3].set(ylim=(0, 75000))
ax[3].set_ylabel('')
ax[3].set_xticklabels(ax[2].get_xticklabels(),rotation = 90)
# Out:
# [Text(0, 0, 'Human factor'),
#  Text(1, 0, 'Other causes'),
#  Text(2, 0, 'Technical failure'),
#  Text(3, 0, 'Terrorism'),
#  Text(4, 0, 'Unknown'),
#  Text(5, 0, 'Weather')]

# %%
# 4 graphs square
import seaborn as sns

plt.style.use('fivethirtyeight') # works but you should also check out the seaborn themes
fig, ax = plt.subplots(2,2,figsize=(20, 10), sharey=True) 
sns.barplot(ax=ax[1,1], x=category0, y=numeric0, # which columns for x and y
                    data=dfgb0, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 
ax[1,1].set_title('Total Deaths by Cause')
ax[1,1].set(ylim=(0, 75000))
ax[1,1].set_ylabel('')
ax[1,1].set_xticklabels(ax[1,1].get_xticklabels(),rotation = 90)

sns.barplot(ax=ax[1,0], x=category1, y=numeric1, # which columns for x and y
                    data=dfgb1, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 
ax[1,0].set_title('Crew Deaths by Cause')
ax[1,0].set(ylim=(0, 75000))
ax[1,0].set_ylabel('')
ax[1,0].set_xticklabels(ax[1,0].get_xticklabels(),rotation = 90)

sns.barplot(ax=ax[0,0], x=category2, y=numeric2, # which columns for x and y
                    data=dfgb2, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 
ax[0,0].set_title('Passenger Deaths by Cause')
ax[0,0].set(ylim=(0, 75000))
ax[0,0].set_ylabel('')
ax[0,0].set_xticklabels(ax[0,0].get_xticklabels(),rotation = 90)

sns.barplot(ax=ax[0,1], x=category3, y=numeric3, # which columns for x and y
                    data=dfgb3, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 
ax[0,1].set_title('Other Deaths by Cause')
ax[0,1].set(ylim=(0, 75000))
ax[0,1].set_ylabel('')
ax[0,1].set_xticklabels(ax[0,1].get_xticklabels(),rotation = 90)
# Out:
# [Text(0, 0, 'Human factor'),
#  Text(1, 0, 'Other causes'),
#  Text(2, 0, 'Technical failure'),
#  Text(3, 0, 'Terrorism'),
#  Text(4, 0, 'Unknown'),
#  Text(5, 0, 'Weather')]

# %%
# 1 graph attempt 1 Not working 
plt.style.use('fivethirtyeight') # works but you should also check out the seaborn themes

print(dfgb0)


fig, ax = plt.subplots(1,1,figsize=(14, 7), sharey=True) 
sns.barplot(ax=ax, x=category0, y=numeric0, hue=numeric01, # which columns for x and y
                    data=dfgb0, # in which dataframe
                    ci=0, # no error bars (much faster!)
                    ) 

ax.set_title('Total Deaths by Cause')
ax.set(ylim=(0, 75000))
ax.set_ylabel('')
ax.set_xticklabels(ax.get_xticklabels(),rotation = 90)
# Out:
#          Crash cause  Total fatalities  PAX fatalities
# 0       Human factor             72955           53247
# 1       Other causes              4002            2746
# 2  Technical failure             29599           20540
# 3          Terrorism             12712            7638
# 4            Unknown             28614           13300
# 5            Weather             10853            7485
# [Text(0, 0, 'Human factor'),
#  Text(1, 0, 'Other causes'),
#  Text(2, 0, 'Technical failure'),
#  Text(3, 0, 'Terrorism'),
#  Text(4, 0, 'Unknown'),
#  Text(5, 0, 'Weather')]

# %%
# 1 graph attempt 2 Not working
dfgb = pd.concat([dfgb0, dfgb1, dfgb2, dfgb3]).reset_index(drop=True)

fig, ax = plt.subplots(figsize=(30, 7))  # new plot

# plot df
ax = sns.lineplot(data=dfgb0, x = 'Crash cause', y = 'Fatalities',label="Total", ci=0)
ax = sns.lineplot(data=dfgb1, x = 'Crash cause', y = 'Fatalities',label="Crew", ci=0)
ax = sns.lineplot(data=dfgb2, x = 'Crash cause', y = 'Fatalities',label="Passenger", ci=0)
ax = sns.lineplot(data=dfgb3, x = 'Crash cause', y = 'Fatalities',label="Other", ci=0)

sns.relplot(data=dfgb, x = 'Crash cause', y = 'Fatalities', kind = 'scatter', palette = ['red', 'blue'])

ax.legend()

# %%
# 1 graph working
name = 'Crash_Cause_By_Fatalities_Bar'

aa=dict(zip(dfgb0['Crash cause'],dfgb0['Fatalities']))
bb=dict(zip(dfgb1['Crash cause'],dfgb1['Fatalities']))
cc=dict(zip(dfgb2['Crash cause'],dfgb2['Fatalities']))
dd=dict(zip(dfgb3['Crash cause'],dfgb3['Fatalities']))

dfbar = pd.DataFrame({'Total Fatalities': aa, 'Crew Fatalities': bb, 'Passenger Fatalities': cc,'Other Fatalities': dd})

# Non-stacked bar plot
graph = dfbar.plot.bar(figsize=(15, 9))

plt.title("Fatalities by Crash Cause")
plt.legend(title="Fatalitiy Type")
plt.xticks(rotation=0)
plt.show()

# %%
# Save Graph
os. chdir("/Users/spencergoergen/documents/HCI_Project/images/")
print(os.getcwd())


fig = graph.get_figure()
fig.savefig(name + ".png")
# Out:
# /Users/spencergoergen/Documents/HCI_Project/images
